# %% [markdown]
# # Ioannou_Georgios

# %% [markdown]
# ## Copyright © 2022 by Georgios Ioannou

# %% [markdown]
# # Exploratory Data Analysis Exercise
#
# - For this part we will be using the `data/cars.csv` dataset.

# %%
# %matplotlib inline 

# import libraries.
from matplotlib import pyplot as plt  # Provides figure().
import numpy as np                    # Provides where(), percentile().
import pandas as pd                   # Provides read_csv(), head(), isin(), value_counts(), sum(), groupby(), count(), mean(), plot().
import seaborn as sns                 # Provides set(), histplot(), regplot(), boxplot(), scatterplot(), pariplot(), heatmap().

sns.set()

df = pd.read_csv('data/cars.csv') # Read the file cars.csv located inside the data folder and then load the data.
df.head()                         # Print/Display/Return the first 5 rows of the file cars.csv
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# ## Load in the data
#
# - Use the file in the data folder called 'cars.csv'.
# - Save it as a varible named 'df'.
# - Display the first 5 rows of our dataframe.

# %%
# Load data.
df = pd.read_csv('data/cars.csv') # Read the file cars.csv located inside the data folder and then load the data.
df.head()                         # Print/Display/Return the first 5 rows of the file cars.csv
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# ## Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print('The number of duplicate rows we have in our dataframe is:', df.duplicated().sum())
print('df.shape:', df.shape) # Print the dimensions (rows, columns) of the dataframe.
# Out:
# The number of duplicate rows we have in our dataframe is: 720
# df.shape: (11914, 15)

# %%
#  2. Modify our df to have all duplicate rows removed.
df = df.drop_duplicates()
print('Dataframe has all duplicate rows removed.')
# Out:
# Dataframe has all duplicate rows removed.

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.
print('The number of duplicate rows we have in our dataframe is:', df.duplicated().sum())
print('df.shape:', df.shape) # Print the dimensions (rows, columns) of the dataframe.
# Out:
# The number of duplicate rows we have in our dataframe is: 0
# df.shape: (11194, 15)

# %% [markdown]
# ## Data clean up part 2.
#
# - Which column has the most null values and how many null values does it have?
# - Print how long our dataframe is.
# - Remove any row that has a null value in it.
# - Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?
df.isnull().sum().sort_values().tail(1)
# Out:
# Engine HP    69
# dtype: int64

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;" >Which column has the most null values and how many null values does it have?</span></center>
# ***
# <span style="color:#964B00;" >The column <b>Engine HP</b> has the most null values. The column <b>Engine HP</b> has <b>69</b> null values.</span>
# ***

# %%
# * Print how long our dataframe is.
print('The dataframe has', len(df), 'rows.')
# Out:
# The dataframe has 11194 rows.

# %%
# * Remove any row that has a null value in it.
df = df.dropna()
print(df.shape) # Print the dimensions (rows, columns) of the dataframe.
# Out:
# (11092, 15)

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.
print(df.shape)
print('The dataframe has', len(df), 'rows.')
# Out:
# (11092, 15)
# The dataframe has 11092 rows.

# %% [markdown]
# ## Make a bar chart that displays how many times each brand of car appears in this data.
#
# _Brand of car is the `Make` of the car._
#
# - You can achieve this by using value_counts or by a groupby. Either is fine with me.

# %%
# Make a bar chart that displays how many times each brand of car appears in this data.
make_counts = df['Make'].value_counts()
make_counts.plot(kind='bar', figsize=(17, 7), title='How many times each brand of car appears in this data');

# %% [markdown]
# ## Make the chart more legible, by making it a horizontal bar chart and changing the figure size. And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
make_counts.plot(kind='barh', figsize=(17, 10), title='How many times each brand of car appears in this data');

# %% [markdown]
# ## Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
#
# - What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
group_by_year = df.groupby('Year')['MSRP'].mean()
group_by_year.plot(figsize=(17, 7), title='Average MSRP vs. Year');

# %% [markdown]
# ## It seems as though in the years before (and includig) 2000, they were counting in tens.
#
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#
# - Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.
df['price_adjuster'] = np.where(df['Year'] <= 2000, 10, 1)

# Multiply the MSRP by the price adjuster.
df['adjusted_price'] = df['MSRP'] * df['price_adjuster']

df.head() # Print/Display/Return the first 5 rows of the file cars.csv with the new column adjusted_price.
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# ...

# %% [markdown]
# ## Replot the new adjusted price.
#
# - Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices.
prices = df.groupby('Year')['adjusted_price'].mean()
prices.plot(ylim=(0, 100000), figsize=(17, 7), title='Average MSRP vs. Year');

# %% [markdown]
# ## What are the top 5 car makers that make the most expensive cars on average?
#
# - I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# - Use our `adjusted_price` column for this
# - Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers that make the most expensive cars on average?
df.groupby('Make')['adjusted_price'].mean().sort_values(ascending=False).head()
# Out:
# Make
# Bugatti        1.757224e+06
# Maybach        5.462219e+05
# Rolls-Royce    3.511306e+05
# Lamborghini    3.315673e+05
# Bentley        2.471693e+05
# Name: adjusted_price, dtype: float64

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;" >What are the top 5 car makers that make the most expensive cars on average?</span></center>
# ***
# <span style="color:#964B00;" >As seen from the results above, the top 5 car makers that make the most expensive cars on average are(first is the most expensive):</span>
# 1. <span style="color:#964B00;" ><b>Bugatti</b></span>
# 2. <span style="color:#964B00;" ><b>Maybach</b></span>
# 3. <span style="color:#964B00;" ><b>Rolls-Royce</b></span>
# 4. <span style="color:#964B00;" ><b>Lamborghini</b></span>
# 5. <span style="color:#964B00;" ><b>Bentley</b></span>
# ***

# %% [markdown]
# ## What are the 5 car makers that have the highest median highway MPG?

# %%
# What are the 5 car makers that have the highest median highway MPG?
df.groupby('Make')['highway MPG'].median().sort_values(ascending=False).head()
# Out:
# Make
# Alfa Romeo    34.0
# FIAT          33.0
# Volkswagen    32.0
# Scion         32.0
# Honda         32.0
# Name: highway MPG, dtype: float64

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;" >What are the 5 car makers that have the highest median highway MPG?</span></center>
# ***
# <span style="color:#964B00;" >As seen from the results above, the 5 car makers that have the highest median highway MPG are(first is the highest):</span>
# 1. <span style="color:#964B00;"><b>Alfa Romeo</b></span>
# 2. <span style="color:#964B00;"><b>FIAT</b></span>
# 3. <span style="color:#964B00;"><b>Volkswagen</b></span>
# 4. <span style="color:#964B00;"><b>Scion</b></span>
# 5. <span style="color:#964B00;"><b>Honda</b></span>
# ***

# %% [markdown]
# ## Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
#
# - ['Chevrolet', 'Ford', 'Toyota']
# - Create a temp_df to store the dataframe of just these values.
# - Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
makers_list = ['Chevrolet', 'Ford', 'Toyota']
temp_df = df[df['Make'].isin(makers_list)]
plt.figure(figsize=(17, 7))
sns.histplot(data=temp_df,
             x='adjusted_price',
             hue='Make').set(title='Count vs. adjusted_price');

# %% [markdown]
# ## Remake the same histogram, but limit the x-axis from 0 to 100,000.

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000.
plt.figure(figsize=(17, 7))
sns.histplot(data=temp_df,
                  x='adjusted_price',
                  hue='Make').set(title='Count vs. adjusted_price');
plt.xlim(0, 100000);

# %% [markdown]
# ## Plot the relationship between Engine HP and highway MPG.

# %%
# Plot the relationship between Engine HP and highway MPG.
plt.figure(figsize=(17, 7))
sns.regplot(data=temp_df,
            x='Engine HP',
            y='highway MPG').set(title='highway MPG vs. Engine HP');

# %% [markdown]
# ## Using `sns.boxplot`, create a boxplot for the 'Engine HP'.

# %%
# Create a boxplot for the 'Engine HP'.
plt.figure(figsize=(19, 3))
sns.boxplot(data=temp_df, x="Engine HP").set(title='Boxplot for the Engine HP');

# %% [markdown]
# ## Make another boxplot for highway MPG.

# %%
# Create a boxplot for the 'highway MPG'.
plt.figure(figsize=(19, 2))
sns.boxplot(data=temp_df, x="highway MPG").set(title='Boxplot for the highway MPG');

# %% [markdown]
# ## Remove any outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# - Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# - For each column (Engine HP and highway MPG):
# - Calculate the 0.25 and 0.75 Quantiles
# - Calculate the Inter Quartile Range (IQR)
# - Create condition mask for the values that are outliers below (in the 'Minimum' range).
# - Create condition mask for the values that are outliers above (in the 'Maximum' range).
# - Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# - Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
# Remove any  outliers from Engine HP and highway MPG.
engine_hp_25 = np.percentile(temp_df['Engine HP'], 25) # 25th Percentile of the Engine HP.
engine_hp_75 = np.percentile(temp_df['Engine HP'], 75) # 75th Percentile of the Engine HP.

engine_hp_iqr = engine_hp_75 - engine_hp_25 # Inter Quartile Range of the Engine HP.

highway_mpg_25 = np.percentile(temp_df['highway MPG'], 25) # 25th Percentile of the highway MPG.
highway_mpg_75 = np.percentile(temp_df['highway MPG'], 75) # 75th Percentile of the highway MPG.

highway_mpg_iqr = highway_mpg_75 - highway_mpg_25 # Inter Quartile Range of the highway MPG.

# Remove any  outliers from Engine HP and highway MPG.
temp_df = temp_df[(temp_df['Engine HP'] < (engine_hp_75 + (engine_hp_iqr * 1.5)))
                  & (temp_df['Engine HP'] > (engine_hp_25 - (engine_hp_iqr * 1.5)))]
temp_df = temp_df[(temp_df['highway MPG'] < (highway_mpg_75 + (highway_mpg_iqr * 1.5)))
                  & (temp_df['highway MPG'] > (highway_mpg_25 - (highway_mpg_iqr * 1.5)))]

# %% [markdown]
# ## Remake the boxplots for both Engine HP and highway MPG.

# %%
# Engine HP boxplot.
plt.figure(figsize=(19, 3))
sns.boxplot(data=temp_df, x="Engine HP").set(title='Boxplot for the Engine HP');

# %%
# highway MPG boxplot.
plt.figure(figsize=(19, 3))
sns.boxplot(data=temp_df, x="highway MPG").set(title='Boxplot for the highway MPG');

# %% [markdown]
# ## Make a scatter plot of Engine HP vs highway MPG.

# %%
# Make a scatter plot of Engine HP vs highway MPG.
plt.figure(figsize=(17, 7))
sns.scatterplot(data=temp_df,
                x='Engine HP',
                y='highway MPG').set(title='Engine HP vs highway MPG');

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;">What does this plot tell you about how Engine HP affects highway MPG?</span></center>
# ***
# - <span style="color:#964B00;">This plot tell us that there is a **negative correlation** between the two variables **Engine HP** and **highway MPG**.</span>
# - <span style="color:#964B00;">More precisely, the **higher** the Engine HP the **lower** the highway MPG.</span>
# - <span style="color:#964B00;">The **increase** of the Engine HP means the **decrease** of the highway MPG.</span>
# ***

# %% [markdown]
# ## Using a pairplot, display all of the linear relationship.
#
# - Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
plt.figure(figsize=(10, 10))
sns.pairplot(temp_df);

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;">Which variables look like they have the strongest linear relationship</span></center>
# ## <center><span style="color:#FFA500;">(Besides MSRP and adjusted_price)?</span></center>
# ***
# <span style="color:#964B00;">Besides the variable MSRP and adjusted_price, the variables **highway MPG** and **city mpg** look like they have the strongest linear relationship.</span>
# ***

# %% [markdown]
# ## Find which features actually have the strongest linear relationship using correlations.
#
# - Make a heatmap plot of all of the correlations in our dataset.
# - Change the figure size of our heatmap plot to be 8x8
# - **Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.**

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8.
plt.figure(figsize=(8, 8))
sns.heatmap(temp_df.corr(), annot=True, cmap='coolwarm');

# %% [markdown]
# ***
# ## <center><span style="color:#FFA500;">Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exist?</span></center>
# ***
# - <span style="color:#964B00;">Informally speaking, **Engine HP** has the strongest relationship with itself(**Engine HP**) as it is the same variable. Correlation of +1.</span>
#
#  - <span style="color:#964B00;">Therefore, if you think of them as two variables, any increase or decrease in one of them it also affects the other one in the same exact way.</span>
#
# - <span style="color:#964B00;">Besides the relationship between Engine HP with itself, **Engine HP** has the strongest relationship with the **Engine Cylinders**. Correlation of +0.77.</span>
#
#  - <span style="color:#964B00;">This relationship exists because the number of Engine Cylinders increases the engine load carrying capacity. Therefore, the output horsepower of the engines will increase with the number of cylinders in the engine.</span>
# ***

# %% [markdown]
# # [EXTRA CREDIT]
#
# - In the column names, replace all the spaces with an underscore, and make them all lowercase as well.

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well.
new_df_column_names_list = []         # new_df_column_names_list stores the new column names.

for column in df.columns:
    # For each column name in the original dataframe, replace all of its spaces with underscores and make all letters lowercase.
    # Finally, append the new column name in the new_df_column_names_list.
    new_df_column_names_list.append(column.replace(' ', '_').lower())

df.columns = new_df_column_names_list # Replace the old column names with the new column names.

df.columns                            # Display the column names of the original dataframe.
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'vehicle_size', 'vehicle_style', 'highway_mpg',
#        'city_mpg', 'popularity', 'msrp', 'price_adjuster', 'adjusted_price'],
#       dtype='object')
